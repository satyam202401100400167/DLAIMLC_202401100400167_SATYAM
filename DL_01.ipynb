# %% [markdown]
# ***TENSORFLOW***

# %%
import tensorflow as tf
import numpy as np

# %%
x = np.array([1,2,3,4],dtype = float)
y = np.array([2,4,6,8],dtype = float)

# %%
model = tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(1)
])

# %%
model.compile(optimizer='sgd', loss = 'mean_squared_error')

# %%
model.fit(x,y,epochs = 10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - loss: 12.4703
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 8.6606
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6.0171
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 4.1828
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 2.9100
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 2.0267
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 1.4138
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.9885
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.6933
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.4885

# %% [markdown]
# ***KERAS***

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x = np.array([1,2,3,4],dtype=float)
y = np.array([2,4,6,8],dtype=float)

# %%
model = Sequential([
    Dense(1,input_shape=(1,))
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='sgd',loss='mse')

# %%
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 2.0857
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 1.4911
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 1.0783
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.7917
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 0.5925
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.4540
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.3577
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2906
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2437
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.2110

# %% [markdown]
# ***PYTORCH***

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
model = nn.Linear(1,1)

# %%
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
x = torch.tensor([[1.,],[2.,],[3.,]])
y = torch.tensor([[2.,],[4.,],[6.,]])

# %%
for epoch in range(10):
  optimizer.zero_grad()
  outputs = model(x)
  loss = criterion(outputs,y)
  loss.backward()
  optimizer.step()
  print(f"Epoch {epoch+1}, Loss: {loss.item()}")
# Out:
# Epoch 1, Loss: 4.101528644561768
# Epoch 2, Loss: 3.242553472518921
# Epoch 3, Loss: 2.5635769367218018
# Epoch 4, Loss: 2.026879072189331
# Epoch 5, Loss: 1.6026463508605957
# Epoch 6, Loss: 1.2673102617263794
# Epoch 7, Loss: 1.0022428035736084
# Epoch 8, Loss: 0.7927183508872986
# Epoch 9, Loss: 0.6270983815193176
# Epoch 10, Loss: 0.4961821138858795
