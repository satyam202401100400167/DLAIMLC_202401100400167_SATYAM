# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# Load dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# Normalize
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)

datagen.fit(X_train)

# %%
datagen.flow(X_train, y_train, batch_size=64)

# %%
model = models.Sequential()

# 1st Convolution Block
model.add(layers.Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)))
model.add(layers.MaxPooling2D((2,2)))

# 2nd Convolution Block
model.add(layers.Conv2D(64, (3,3), activation='relu'))
model.add(layers.MaxPooling2D((2,2)))

# 3rd Convolution Block
model.add(layers.Conv2D(64, (3,3), activation='relu'))

# Flatten
model.add(layers.Flatten())

# Fully Connected Layer
model.add(layers.Dense(64, activation='relu'))

# Dropout Layer
model.add(layers.Dropout(0.5))

# Output Layer
model.add(layers.Dense(10, activation='softmax'))

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    datagen.flow(X_train, y_train, batch_size=64),
    epochs=20,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 42ms/step - accuracy: 0.2165 - loss: 2.0639 - val_accuracy: 0.4436 - val_loss: 1.5526
# Epoch 2/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.3973 - loss: 1.6342 - val_accuracy: 0.5096 - val_loss: 1.3439
# Epoch 3/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.4499 - loss: 1.5121 - val_accuracy: 0.5374 - val_loss: 1.2846
# Epoch 4/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.4925 - loss: 1.4218 - val_accuracy: 0.5860 - val_loss: 1.1496
# Epoch 5/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.5151 - loss: 1.3624 - val_accuracy: 0.5855 - val_loss: 1.1661
# Epoch 6/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.5392 - loss: 1.3116 - val_accuracy: 0.6001 - val_loss: 1.1271
# Epoch 7/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.5475 - loss: 1.2845 - val_accuracy: 0.6220 - val_loss: 1.0653
# Epoch 8/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.5614 - loss: 1.2539 - val_accuracy: 0.6094 - val_loss: 1.0947
# Epoch 9/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.5720 - loss: 1.2191 - val_accuracy: 0.6345 - val_loss: 1.0610
# Epoch 10/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.5824 - loss: 1.1989 - val_accuracy: 0.6449 - val_loss: 0.9959
# Epoch 11/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.5950 - loss: 1.1618 - val_accuracy: 0.6738 - val_loss: 0.9249
# Epoch 12/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6028 - loss: 1.1416 - val_accuracy: 0.6677 - val_loss: 0.9606
# Epoch 13/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.6087 - loss: 1.1209 - val_accuracy: 0.6748 - val_loss: 0.9341
# Epoch 14/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.6097 - loss: 1.1207 - val_accuracy: 0.6834 - val_loss: 0.9141
# Epoch 15/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.6211 - loss: 1.0929 - val_accuracy: 0.6520 - val_loss: 1.0053
# Epoch 16/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6307 - loss: 1.0690 - val_accuracy: 0.6899 - val_loss: 0.8910
# Epoch 17/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6355 - loss: 1.0587 - val_accuracy: 0.6899 - val_loss: 0.8850
# Epoch 18/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.6421 - loss: 1.0428 - val_accuracy: 0.6726 - val_loss: 0.9346
# Epoch 19/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6410 - loss: 1.0386 - val_accuracy: 0.6952 - val_loss: 0.8941
# Epoch 20/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.6495 - loss: 1.0234 - val_accuracy: 0.7002 - val_loss: 0.8597
